# %% [markdown]
# <a href="https://colab.research.google.com/github/Aryanfour5/DropoutAnalysis/blob/main/Drop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import os
sb.set(color_codes=True)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path="/content/drive/MyDrive/dataset.csv"
df=pd.read_csv(path)
df.head(148)
# Out:
#     Gender  Age  SleepingHours Music  GamingHours  Distance  AverageScore  \
# 0        F   23            5.5   Yes          2.5     38.12           8.1
# 1        M   26            5.0    No          1.5     56.74           7.8
# 2        M   29            4.0   Yes          3.5     75.82           6.4
# 3        F   20            6.5   Yes          1.0     43.89           7.2
# 4        M   31            6.0    No          0.5     61.93           6.8
# ..     ...  ...            ...   ...          ...       ...           ...
# 139      F   30            3.5   Yes          2.5     38.28           5.6
# 140      M   24            6.0   Yes          0.5     71.54           8.8
# 141      F   28            5.0    No          1.0     52.87           7.5
# 142      M   33            5.5   Yes          1.0     62.38           6.7
# 143      F   25            4.5   Yes          2.0     74.92           8.9
#
#     Dropout
# 0        No
# 1        No
# 2       Yes
# 3        No
# ...

# %%
df.dtypes
# Out:
# Gender            object
# Age                int64
# SleepingHours    float64
# Music             object
# GamingHours      float64
# Distance         float64
# AverageScore     float64
# Dropout           object
# dtype: object

# %%
df.describe()
# Out:
#               Age  SleepingHours  GamingHours    Distance  AverageScore
# count  144.000000     144.000000   144.000000  144.000000    144.000000
# mean    25.527778       5.090278     1.885417   59.850139      7.340278
# std      4.222723       0.880346     1.195444   16.083897      1.028701
# min     18.000000       3.500000     0.500000   28.560000      5.400000
# 25%     22.000000       4.500000     1.000000   48.682500      6.600000
# 50%     25.000000       5.000000     1.500000   60.770000      7.500000
# 75%     29.000000       6.000000     3.000000   72.652500      8.100000
# max     33.000000       6.500000     4.000000   93.720000      9.500000

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'SleepingHours', 'Music', 'GamingHours', 'Distance',
#        'AverageScore', 'Dropout'],
#       dtype='object')

# %%
df.hist(figsize=(40,30))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'SleepingHours'}>],
#        [<Axes: title={'center': 'GamingHours'}>,
#         <Axes: title={'center': 'Distance'}>],
#        [<Axes: title={'center': 'AverageScore'}>, <Axes: >]], dtype=object)

# %%
sb.boxplot(x="Age",y="Dropout",data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Dropout'>

# %%
sb.boxplot(x="AverageScore",y="Dropout",data=df)
# Out:
# <Axes: xlabel='AverageScore', ylabel='Dropout'>

# %%
sb.pairplot(df)

# %%
df.count()
# Out:
# Gender           144
# Age              144
# SleepingHours    144
# Music            144
# GamingHours      144
# Distance         144
# AverageScore     144
# Dropout          144
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#     Gender  Age  SleepingHours Music  GamingHours  Distance  AverageScore  \
# 0        F   23            5.5   Yes          2.5     38.12           8.1
# 1        M   26            5.0    No          1.5     56.74           7.8
# 2        M   29            4.0   Yes          3.5     75.82           6.4
# 3        F   20            6.5   Yes          1.0     43.89           7.2
# 4        M   31            6.0    No          0.5     61.93           6.8
# ..     ...  ...            ...   ...          ...       ...           ...
# 134      M   31            4.0   Yes          3.5     54.29           5.7
# 136      M   26            4.5    No          1.5     37.97           8.1
# 138      M   21            6.5    No          0.5     53.74           7.9
# 142      M   33            5.5   Yes          1.0     62.38           6.7
# 143      F   25            4.5   Yes          2.0     74.92           8.9
#
#     Dropout
# 0        No
# 1        No
# 2       Yes
# 3        No
# ...

# %%
plt.figure(figsize=(30,20))
d=df.corr()
sb.heatmap(d,cmap="autumn",annot=True)
d
# Out:
# <ipython-input-60-eb1074e5eaa7>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   d=df.corr()
#                     Age  SleepingHours  GamingHours  Distance  AverageScore
# Age            1.000000       0.020013    -0.156942  0.025612     -0.093791
# SleepingHours  0.020013       1.000000    -0.539958  0.317073      0.304831
# GamingHours   -0.156942      -0.539958     1.000000  0.192840     -0.314949
# Distance       0.025612       0.317073     0.192840  1.000000      0.019357
# AverageScore  -0.093791       0.304831    -0.314949  0.019357      1.000000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
# ...
