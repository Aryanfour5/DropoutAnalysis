# %% [markdown]
# <a href="https://colab.research.google.com/github/Aryanfour5/DropoutAnalysis/blob/main/Copy_of_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import os
import warnings

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path="/content/drive/MyDrive/Final_Gujarat.csv"
df=pd.read_csv(path)
df
# Out:
#       Class  Previous qualification (grade)  Gender  \
# 0         4                           130.0       0
# 1         4                           137.0       0
# 2         4                           188.0       0
# 3         4                           127.0       0
# 4         4                           115.0       0
# ...     ...                             ...     ...
# 4419     10                           120.0       1
# 4420     10                           140.0       1
# 4421     10                           160.0       1
# 4422     10                           133.1       1
# 4423     10                           140.0       1
#
#       Curricular units 1st sem (grade)  Curricular units 2nd sem (grade)  \
# 0                            12.000000                         11.000000
# 1                             0.000000                          0.000000
# 2                             0.000000                          0.000000
# 3                             0.000000                          0.000000
# 4                             0.000000                          0.000000
# ...                                ...                               ...
# 4419                         14.800000                         14.200000
# 4420                         12.333333                         12.000000
# 4421                         12.600000                         13.714286
# 4422                         14.714286                         14.375000
# 4423                         14.600000                         14.333333
#
#        Region      School  Age Caste    Target
# 0       Kolat  Government   10   GEN   Dropout
# 1       Kolat  Government   10   OBC   Dropout
# 2       Kolat  Government   10   GEN   Dropout
# 3     Jetapur  Government   10   OBC   Dropout
# 4     Jetapur  Government   10    SC   Dropout
# ...       ...         ...  ...   ...       ...
# 4419    Sadra  Government   16   GEN  Studying
# 4420    Sadra     Private   16    ST  Studying
# 4421    Sadra  Government   16    SC  Studying
# 4422    Melaj  Government   16    ST  Studying
# 4423    Melaj  Government   16   GEN  Studying
#
# [4424 rows x 10 columns]

# %%
df.dtypes
# Out:
# Class                                 int64
# Previous qualification (grade)      float64
# Gender                                int64
# Curricular units 1st sem (grade)    float64
# Curricular units 2nd sem (grade)    float64
# Region                               object
# School                               object
# Age                                   int64
# Caste                                object
# Target                               object
# dtype: object

# %%
df.describe()
# Out:
#              Class  Previous qualification (grade)       Gender  \
# count  4424.000000                     4424.000000  4424.000000
# mean      7.997288                      132.613314     0.591772
# std       1.714270                       13.188332     0.491561
# min       4.000000                       95.000000     0.000000
# 25%       6.000000                      125.000000     0.000000
# 50%       9.000000                      133.100000     1.000000
# 75%       9.000000                      140.000000     1.000000
# max      10.000000                      190.000000     1.000000
#
#        Curricular units 1st sem (grade)  Curricular units 2nd sem (grade)  \
# count                       4424.000000                       4424.000000
# mean                          10.640822                         10.230206
# std                            4.843663                          5.210808
# min                            0.000000                          0.000000
# 25%                           11.000000                         10.750000
# 50%                           12.285714                         12.200000
# 75%                           13.400000                         13.333333
# max                           18.875000                         18.571429
#
#                Age
# count  4424.000000
# mean     13.997288
# std       1.714270
# min      10.000000
# 25%      12.000000
# 50%      15.000000
# 75%      15.000000
# max      16.000000

# %%
df.columns
# Out:
# Index(['Class', 'Previous qualification (grade)', 'Gender',
#        'Curricular units 1st sem (grade)', 'Curricular units 2nd sem (grade)',
#        'Region', 'School', 'Age', 'Caste', 'Target'],
#       dtype='object')

# %%
df.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of       Class  Previous qualification (grade)  Gender  \
# 0     False                           False   False
# 1     False                           False   False
# 2     False                           False   False
# 3     False                           False   False
# 4     False                           False   False
# ...     ...                             ...     ...
# 4419  False                           False   False
# 4420  False                           False   False
# 4421  False                           False   False
# 4422  False                           False   False
# 4423  False                           False   False
#
#       Curricular units 1st sem (grade)  Curricular units 2nd sem (grade)  \
# 0                                False                             False
# 1                                False                             False
# 2                                False                             False
# 3                                False                             False
# 4                                False                             False
# ...                                ...                               ...
# 4419                             False                             False
# 4420                             False                             False
# 4421                             False                             False
# 4422                             False                             False
# 4423                             False                             False
#
#       Region  School    Age  Caste  Target
# 0      False   False  False  False   False
# 1      False   False  False  False   False
# 2      False   False  False  False   False
# 3      False   False  False  False   False
# 4      False   False  False  False   False
# ...      ...     ...    ...    ...     ...
# 4419   False   False  False  False   False
# 4420   False   False  False  False   False
# 4421   False   False  False  False   False
# 4422   False   False  False  False   False
# 4423   False   False  False  False   False
#
# [4424 rows x 10 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 10 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Class                             4424 non-null   int64
#  1   Previous qualification (grade)    4424 non-null   float64
#  2   Gender                            4424 non-null   int64
#  3   Curricular units 1st sem (grade)  4424 non-null   float64
#  4   Curricular units 2nd sem (grade)  4424 non-null   float64
#  5   Region                            4424 non-null   object
#  6   School                            4424 non-null   object
#  7   Age                               4424 non-null   int64
#  8   Caste                             4424 non-null   object
#  9   Target                            4424 non-null   object
# dtypes: float64(3), int64(3), object(4)
# memory usage: 345.8+ KB

# %%
df.hist(figsize=(40,30))
# Out:
# array([[<Axes: title={'center': 'Class'}>,
#         <Axes: title={'center': 'Previous qualification (grade)'}>],
#        [<Axes: title={'center': 'Gender'}>,
#         <Axes: title={'center': 'Curricular units 1st sem (grade)'}>],
#        [<Axes: title={'center': 'Curricular units 2nd sem (grade)'}>,
#         <Axes: title={'center': 'Age'}>]], dtype=object)

# %%
df.count()
# Out:
# Class                               4424
# Previous qualification (grade)      4424
# Gender                              4424
# Curricular units 1st sem (grade)    4424
# Curricular units 2nd sem (grade)    4424
# Region                              4424
# School                              4424
# Age                                 4424
# Caste                               4424
# Target                              4424
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#       Class  Previous qualification (grade)  Gender  \
# 0         4                           130.0       0
# 1         4                           137.0       0
# 2         4                           188.0       0
# 3         4                           127.0       0
# 4         4                           115.0       0
# ...     ...                             ...     ...
# 4419     10                           120.0       1
# 4420     10                           140.0       1
# 4421     10                           160.0       1
# 4422     10                           133.1       1
# 4423     10                           140.0       1
#
#       Curricular units 1st sem (grade)  Curricular units 2nd sem (grade)  \
# 0                            12.000000                         11.000000
# 1                             0.000000                          0.000000
# 2                             0.000000                          0.000000
# 3                             0.000000                          0.000000
# 4                             0.000000                          0.000000
# ...                                ...                               ...
# 4419                         14.800000                         14.200000
# 4420                         12.333333                         12.000000
# 4421                         12.600000                         13.714286
# 4422                         14.714286                         14.375000
# 4423                         14.600000                         14.333333
#
#        Region      School  Age Caste    Target
# 0       Kolat  Government   10   GEN   Dropout
# 1       Kolat  Government   10   OBC   Dropout
# 2       Kolat  Government   10   GEN   Dropout
# 3     Jetapur  Government   10   OBC   Dropout
# 4     Jetapur  Government   10    SC   Dropout
# ...       ...         ...  ...   ...       ...
# 4419    Sadra  Government   16   GEN  Studying
# 4420    Sadra     Private   16    ST  Studying
# 4421    Sadra  Government   16    SC  Studying
# 4422    Melaj  Government   16    ST  Studying
# 4423    Melaj  Government   16   GEN  Studying
#
# [4375 rows x 10 columns]

# %%
sb.pairplot(df,hue="Gender", diag_kind="hist")

# %%
sb.pairplot(df,hue="Class", diag_kind="hist")

# %%
sb.pairplot(df,hue="Caste", diag_kind="hist")

# %%
from sklearn import tree
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression,Perceptron
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score, classification_report,confusion_matrix,ConfusionMatrixDisplay

# %%
df['School'].value_counts()
# Out:
# Government    3122
# Private       1302
# Name: School, dtype: int64

# %%
df['School'] = LabelEncoder().fit_transform(df['School'])

# %%
df['School'].value_counts()
# Out:
# 0    3122
# 1    1302
# Name: School, dtype: int64

# %%
df['Target'].value_counts()
# Out:
# Studying    3003
# Dropout     1421
# Name: Target, dtype: int64

# %%
df['Target'] = LabelEncoder().fit_transform(df['Target'])

# %%
df['Target'].value_counts()
# Out:
# 1    3003
# 0    1421
# Name: Target, dtype: int64

# %%
df['Caste'] = LabelEncoder().fit_transform(df['Caste'])

# %%
df['Caste'].value_counts()
# Out:
# 0    1996
# 2     890
# 1     877
# 3     661
# Name: Caste, dtype: int64

# %%
df['Region'] = LabelEncoder().fit_transform(df['Region'])

# %%
df['Region'].value_counts()
# Out:
# 6    456
# 2    453
# 8    448
# 0    447
# 1    447
# 7    447
# 9    445
# 4    443
# 3    442
# 5    396
# Name: Region, dtype: int64

# %%
plt.figure(figsize=(5, 10))
sb.distplot(df['Target'],color="Green")
# Out:
# <ipython-input-127-da5a61dc4644>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(df['Target'],color="Green")
# <Axes: xlabel='Target', ylabel='Density'>

# %%
plt.figure(figsize=(30,20))
d=df.corr(method="pearson")
sb.heatmap(d,cmap="YlGnBu",annot=True)
d
# Out:
#                                      Class  Previous qualification (grade)  \
# Class                             1.000000                        0.059906
# Previous qualification (grade)    0.059906                        1.000000
# Gender                            0.174156                       -0.010342
# Curricular units 1st sem (grade)  0.499183                        0.059438
# Curricular units 2nd sem (grade)  0.584206                        0.053239
# Region                            0.000591                        0.018885
# School                            0.172616                        0.005107
# Age                               1.000000                        0.059906
# Caste                            -0.014807                       -0.018424
# Target                            0.945300                        0.078208
#
#                                     Gender  Curricular units 1st sem (grade)  \
# Class                             0.174156                          0.499183
# Previous qualification (grade)   -0.010342                          0.059438
# Gender                            1.000000                          0.063843
# Curricular units 1st sem (grade)  0.063843                          1.000000
# Curricular units 2nd sem (grade)  0.092921                          0.837170
# Region                            0.022874                         -0.006176
# School                            0.135741                          0.061755
# Age                               0.174156                          0.499183
# Caste                             0.002955                         -0.009677
# Target                            0.137797                          0.480669
#
#                                   Curricular units 2nd sem (grade)    Region  \
# Class                                                     0.584206  0.000591
# Previous qualification (grade)                            0.053239  0.018885
# Gender                                                    0.092921  0.022874
# Curricular units 1st sem (grade)                          0.837170 -0.006176
# Curricular units 2nd sem (grade)                          1.000000 -0.008944
# Region                                                   -0.008944  1.000000
# School                                                    0.083788  0.006316
# Age                                                       0.584206  0.000591
# Caste                                                    -0.002333  0.013886
# Target                                                    0.571792 -0.000987
#
#                                     School       Age     Caste    Target
# Class                             0.172616  1.000000 -0.014807  0.945300
# Previous qualification (grade)    0.005107  0.059906 -0.018424  0.078208
# Gender                            0.135741  0.174156  0.002955  0.137797
# Curricular units 1st sem (grade)  0.061755  0.499183 -0.009677  0.480669
# Curricular units 2nd sem (grade)  0.083788  0.584206 -0.002333  0.571792
# Region                            0.006316  0.000591  0.013886 -0.000987
# School                            1.000000  0.172616  0.013513  0.183984
# Age                               0.172616  1.000000 -0.014807  0.945300
# Caste                             0.013513 -0.014807  1.000000 -0.021939
# Target                            0.183984  0.945300 -0.021939  1.000000

# %%
plt.figure(figsize=(20, 45))

for i in range(0, 5):
    plt.subplot(12,3,i+1)
    sb.distplot(df.iloc[:, i], color='blue')
    plt.grid()
# Out:
# <ipython-input-130-28c19011bb2a>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(df.iloc[:, i], color='blue')
# <ipython-input-130-28c19011bb2a>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(df.iloc[:, i], color='blue')
# <ipython-input-130-28c19011bb2a>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(df.iloc[:, i], color='blue')
# <ipython-input-130-28c19011bb2a>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(df.iloc[:, i], color='blue')
# <ipython-input-130-28c19011bb2a>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(df.iloc[:, i], color='blue')

# %%
x = df.drop('Target',axis=1)
y = df['Target']

# %%
x = df.iloc[:, :5].values
#x = df[["Tuition fees up to date","Curricular units 1st sem (approved)","Curricular units 1st sem (grade)","Curricular units 2nd sem (approved)","Curricular units 2nd sem (grade)"]].values
print(x)
x = StandardScaler().fit_transform(x)
x
# Out:
# [[  4.         130.           0.          12.          11.        ]
#  [  4.         137.           0.           0.           0.        ]
#  [  4.         188.           0.           0.           0.        ]
#  ...
#  [ 10.         160.           1.          12.6         13.71428571]
#  [ 10.         133.1          1.          14.71428571  14.375     ]
#  [ 10.         140.           1.          14.6         14.33333333]]
# array([[-2.33203586, -0.19817587, -1.20399851,  0.28064132,  0.14774701],
#        [-2.33203586,  0.33265634, -1.20399851, -2.19710239, -1.96348862],
#        [-2.33203586,  4.20014816, -1.20399851, -2.19710239, -1.96348862],
#        ...,
#        [ 1.16839164,  2.07681932,  0.83056581,  0.4045285 ,  0.66870126],
#        [ 1.16839164,  0.03690696,  0.83056581,  0.84108334,  0.79551249],
#        [ 1.16839164,  0.56015586,  0.83056581,  0.81748579,  0.78751538]])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 1)

# %%
def perform(y_pred):
    print("Precision : ", precision_score(y_test, y_pred, average = 'micro'))
    print("Recall : ", recall_score(y_test, y_pred, average = 'micro'))
    print("Accuracy : ", accuracy_score(y_test, y_pred))
    print("F1 Score : ", f1_score(y_test, y_pred, average = 'micro'))
    cm = confusion_matrix(y_test, y_pred)
    print("\n", cm)
    print("\n")
    print("**"*27 + "\n" + " "* 16 + "Classification Report\n" + "**"*27)
    print(classification_report(y_test, y_pred))
    print("**"*27+"\n")

    cm = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels=['Studying', 'Dropout'])
    cm.plot()

# %%
model_lr = LogisticRegression()
model_lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred_lr = model_lr.predict(x_test)

# %%
perform(y_pred_lr)
# Out:
# Precision :  0.9954802259887006
# Recall :  0.9954802259887006
# Accuracy :  0.9954802259887006
# F1 Score :  0.9954802259887006
#
#  [[273   4]
#  [  0 608]]
#
#
# ******************************************************
#                 Classification Report
# ******************************************************
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       277
#            1       0.99      1.00      1.00       608
#
#     accuracy                           1.00       885
#    macro avg       1.00      0.99      0.99       885
# weighted avg       1.00      1.00      1.00       885
#
# ******************************************************

# %%
from sklearn.svm import SVC
SVCClf = SVC(kernel = 'rbf')
SVCClf.fit(x, y)
# Out:
# SVC()

# %%
y_pred_svc = SVCClf.predict(x_test)

# %%
acs = accuracy_score(y_test, y_pred_svc)
acs
# Out:
# 0.9966101694915255

# %%
cn= confusion_matrix(y_test, y_pred_svc)
cn
cd = ConfusionMatrixDisplay(confusion_matrix = cn, display_labels=['Studying', 'Dropout'])
cd.plot()

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(x, y)

# %%
Y_pred_DTC = clf.predict(x_test)

# %%
acs = accuracy_score(y_test, Y_pred_DTC)
acs
# Out:
# 0.9988700564971752

# %%
cm= confusion_matrix(y_test, Y_pred_DTC)
cm
cd = ConfusionMatrixDisplay(confusion_matrix = cn, display_labels=['Studying', 'Dropout'])
cd.plot()

# %%
clf = RandomForestClassifier(random_state=0)
clf.fit(x, y)
# Out:
# RandomForestClassifier(random_state=0)

# %%
y_pred_RFC = clf.predict(x_test)
acs = accuracy_score(y_test, y_pred_RFC)
acs
# Out:
# 0.9988700564971752

# %%
cm= confusion_matrix(y_test, y_pred_RFC)
cm
cd = ConfusionMatrixDisplay(confusion_matrix = cn, display_labels=['Studying', 'Dropout'])
cd.plot()

# %%
pred=[y_pred_lr,y_pred_RFC,y_pred_svc,Y_pred_DTC]
acc=[]
classifiers=["Logistic Regression","RandomForestClassifier","Support Vector Classier","DecisionTree"]
for i in pred:
    temp=accuracy_score(y_test, i)
    acc.append(temp)
plt.barh(classifiers, acc)
plt.ylabel('classifiers')
plt.xlabel('Accuracy')
plt.title('Comparison')
plt.show()
